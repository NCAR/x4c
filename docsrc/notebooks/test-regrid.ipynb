# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('/glade/u/home/fengzhu/Github/x4c/docsrc/notebooks')
import numpy as np
import x4c
print(x4c.__version__)
# Out:
# 2026.3.9

# %%
# ds_old = x4c.open_dataset('/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.005.offset.d18O.branch/atm/proc/tseries/month_1/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.005.offset.d18O.branch.cam.h0.TS.200101-205012.nc')
# ds_old

# %%
# dirpath = '/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/test'
# fname = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005.offset.d18O.branch.cam.h0.TS.750101-750112.nc'
# case = x4c.Timeseries(dirpath)

# %%
# ds = x4c.load_dataset(os.path.join(dirpath, fname))
# ds['TS']

# %%
ds = x4c.open_dataset('b.e13.BHISTC5.ne120_t12.cesm-ihesp-hires1.0.46-1920-2005.010.cam.h0.U.200001-200512.nc')
ds['U']
# Out:
# <xarray.DataArray 'U' (time: 72, lev: 30, ncol: 777602)> Size: 7GB
# [1679620320 values with dtype=float32]
# Coordinates:
#   * time     (time) object 576B 2000-02-01 00:00:00 ... 2006-01-01 00:00:00
#   * lev      (lev) float64 240B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
# Dimensions without coordinates: ncol
# Attributes:
#     mdims:         1
#     units:         m/s
#     long_name:     Zonal wind
#     cell_methods:  time: mean

# %%
ds.attrs['comp'] = 'atm'
ds.attrs['grid'] = 'ne120np4'

ds_rgd = ds.x.regrid()
ds_rgd
# Out:
# <xarray.Dataset> Size: 560MB
# Dimensions:        (lev: 30, ilev: 31, cosp_prs: 7, nbnd: 2, cosp_tau: 7,
#                     cosp_ht: 40, cosp_sr: 15, time: 72, cosp_scol: 50,
#                     cosp_sza: 5, lat: 180, lon: 360)
# Coordinates:
#   * lev            (lev) float64 240B 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * ilev           (ilev) float64 248B 2.255 5.032 10.16 ... 967.5 985.1 1e+03
#   * cosp_prs       (cosp_prs) float64 56B 900.0 740.0 620.0 ... 375.0 245.0 90.0
#   * cosp_tau       (cosp_tau) float64 56B 0.15 0.8 2.45 6.5 16.2 41.5 219.5
#   * cosp_ht        (cosp_ht) float64 320B 240.0 720.0 ... 1.848e+04 1.896e+04
#   * cosp_sr        (cosp_sr) float64 120B 0.605 2.1 4.0 ... 70.0 539.5 1.004e+03
#   * time           (time) object 576B 2000-02-01 00:00:00 ... 2006-01-01 00:0...
#   * cosp_scol      (cosp_scol) int32 200B 1 2 3 4 5 6 7 ... 44 45 46 47 48 49 50
#   * cosp_sza       (cosp_sza) float64 40B 0.0 15.0 30.0 45.0 60.0
# ...

# %%
ds_rgd['U']
# Out:
# <xarray.DataArray 'U' (time: 72, lev: 30, lat: 180, lon: 360)> Size: 560MB
# array([[[[-1.21323240e+00, -1.21315920e+00, -1.21301258e+00, ...,
#           -1.21301258e+00, -1.21315920e+00, -1.21323240e+00],
#          [-1.58338797e+00, -1.58187461e+00, -1.55053353e+00, ...,
#           -1.61390054e+00, -1.58448386e+00, -1.58338797e+00],
#          [-1.97600436e+00, -1.95624089e+00, -1.93965590e+00, ...,
#           -2.01224494e+00, -1.99622464e+00, -1.97600436e+00],
#          ...,
#          [-8.36268616e+01, -8.47923584e+01, -8.57520523e+01, ...,
#           -8.09039307e+01, -8.21442947e+01, -8.36268616e+01],
#          [-8.48931885e+01, -8.49709396e+01, -8.67505417e+01, ...,
#           -8.22372360e+01, -8.47888260e+01, -8.48931885e+01],
#          [-8.55091095e+01, -8.55091782e+01, -8.55093155e+01, ...,
#           -8.55093155e+01, -8.55091782e+01, -8.55091095e+01]],
#
#         [[-1.70377064e+00, -1.70373178e+00, -1.70365405e+00, ...,
# ...
